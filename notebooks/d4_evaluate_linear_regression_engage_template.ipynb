# %% [markdown]
# # D4: Evaluate Linear Regression & Engage
#
# Use this notebook to draft your discussion response. Keep headings and numbered prompts exactly as required by the assignment.

# %% [markdown]
# ## Quick Workflow
#
# 1. Open the Comparison App running in PyShiny.
# 2. Run Dataset 1 with two methods; record slope/intercept and take screenshot.
# 3. Run Dataset 2 with two methods; record slope/intercept and take screenshot.
# 4. Fill in all sections below with numbered prompts.
# 5. Add reply content for one classmate at the end.

# %% [markdown]
# ## Part 1 - Technical Support
#
# **1. How are things going so far:** Going good.
#
# **2. Questions or concerns (ask them here):** Not at this time.

# %% [markdown]
# ## Part 2 - Comparison 1 / Dataset 1
#
# **1. Your name:** Angie Crews
#
# **2. Method 1:** NumPy
#
# **3. Method 2:** Scikit-Learn
#
# **4. Discuss and compare these two methods and their results for Dataset 1. Be specific, use numbers:** Both methods produced the same regression line for Dataset 1. NumPy gave a slope of 2.055 and an intercept of -0.196, and Scikit-Learn also gave a slope of 2.055 and an intercept of -0.196. The lines overlap visually, so the models are essentially identical for this dataset. The difference in slope is 0.000 and the difference in intercept is 0.000.

# %% [markdown]
# ### 5. Dataset 1 Screenshot
#
# Save your screenshot as `dataset1_comparison.png`. If the markdown image does not render, run the next code cell:
#
# ![Dataset 1 Screenshot](dataset1_comparison.png)

# %%
from pathlib import Path

from IPython.display import Image, display

candidates = [
    Path('dataset1_comparison.png'),
    Path('notebooks/dataset1_comparison.png'),
    Path('ml-04-regression/notebooks/dataset1_comparison.png'),
]

for p in candidates:
    if p.exists():
        display(Image(filename=str(p)))
        print(f'Displaying: {p.resolve()}')
        break
else:
    print('Screenshot not found. Checked:')
    for p in candidates:
        print(' -', p.resolve())

# %% [markdown]
# ## Part 3 - Comparison 2 / Dataset 2
#
# **1. Method 1:** Scikit-Learn
#
# **2. Method 2:** Scikit-Learn Huber
#
# **3. Discuss and compare these two methods and their results for Dataset 2. Be specific, use numbers:** The two methods are very different on Dataset 2 because of the outlier near x=8, y=100. Scikit-Learn produced a slope of 9.021 and an intercept of -21.096, while Scikit-Learn Huber produced a slope of 2.165 and an intercept of -0.517. That means the slope differs by 6.856 and the intercept differs by 20.579. Scikit-Learn Huber performed better for this dataset because it is robust to outliers and kept the fitted line close to the main cluster of points instead of being pulled sharply upward by the outlier.

# %% [markdown]
# ### 4. Dataset 2 Screenshot
#
# Save your screenshot as `dataset2_comparison.png`. If the markdown image does not render, run the next code cell:
#
# ![Dataset 2 Screenshot](dataset2_comparison.png)

# %%
from pathlib import Path

from IPython.display import Image, display

candidates = [
    Path('dataset2_comparison.png'),
    Path('notebooks/dataset2_comparison.png'),
    Path('ml-04-regression/notebooks/dataset2_comparison.png'),
]

for p in candidates:
    if p.exists():
        display(Image(filename=str(p)))
        print(f'Displaying: {p.resolve()}')
        break
else:
    print('Screenshot not found. Checked:')
    for p in candidates:
        print(' -', p.resolve())

# %% [markdown]
# ## Optional Comparison 3 / Dataset 3
#
# **1. Did you try different data (y/n):** Yes
#
# **2. How did you change the example to use your custom data:** I added xlist3 and ylist3 to the utils.py file. I then imported them into app.py, added Dataset 3 to the dropdown menu, and updated the getXY() function so the app would use the new data when Dataset 3 was selected.
#
# **3. Describe your custom data:** My custom data represents hours studied and test scores. The study hours range from 1 to 8, and most scores increase as study time increases. I included one outlier where a student studied 8 hours but scored only 55.
#
# **4. Method 1:** Scikit-Learn
#
# **5. Method 2:** Scikit-Learn Huber
#
# **6. Discuss and compare these two methods and their results for your Dataset 3. Be specific, use numbers:** Scikit-Learn produced a slope of approximately 2.560 and an intercept of 55.857. Scikit-Learn Huber produced a slope of approximately 5.546 and an intercept of 46.892. The low score of 55 at 8 study hours pulled the regular Scikit-Learn regression line downward and lowered its slope. Huber was less affected by the outlier, so its line followed the pattern of the other seven data points more closely.
#
# **7. What did you learn:** I learned that one unusual data point can significantly change a regular linear regression line. Huber regression reduces the effect of outliers and can better represent the main pattern in the data.

# %% [markdown]
# ### 8. Dataset 3 Screenshot
#
# Save your screenshot as `dataset3_comparison.png`. If the markdown image does not render, run the next code cell:
#
# ![Dataset 3 Screenshot](dataset3_comparison.png)

# %%
from pathlib import Path

from IPython.display import Image, display

candidates = [
    Path('dataset3_comparison.png'),
    Path('notebooks/dataset3_comparison.png'),
    Path('ml-04-regression/notebooks/dataset3_comparison.png'),
]

for p in candidates:
    if p.exists():
        display(Image(filename=str(p)))
        print(f'Displaying: {p.resolve()}')
        break
else:
    print('Screenshot not found. Checked:')
    for p in candidates:
        print(' -', p.resolve())
